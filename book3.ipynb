# %%
import pandas as pd
import matplotlib.pyplot as plt
smokers = pd.read_csv('comparing-the-share-of-men-and-women-who-are-smoking.csv')
smokers
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1800
# 2        Afghanistan       AFG  1801
# 3        Afghanistan       AFG  1802
# 4        Afghanistan       AFG  1803
# ...              ...       ...   ...
# 47277       Zimbabwe       ZWE  2009
# 47278       Zimbabwe       ZWE  2017
# 47279       Zimbabwe       ZWE  2018
# 47280       Zimbabwe       ZWE  2019
# 47281  Åland Islands       ALA  2015
#
#        Smoking prevalence, females (% of adults)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 47277                                        NaN
# 47278                                        NaN
# 47279                                        NaN
# ...

# %%
colombiaSmokers = smokers[smokers.Entity == 'Colombia']

# %%
colombiaSmokers
# Out:
#         Entity Code  Year  Smoking prevalence, females (% of adults)  \
# 8751  Colombia  COL  2000                                       13.1
# 8752  Colombia  COL  2005                                        9.4
# 8753  Colombia  COL  2010                                        6.8
# 8754  Colombia  COL  2011                                        6.4
# 8755  Colombia  COL  2012                                        6.0
# ...        ...  ...   ...                                        ...
# 8966  Colombia  COL  2008                                        NaN
# 8967  Colombia  COL  2009                                        NaN
# 8968  Colombia  COL  2017                                        NaN
# 8969  Colombia  COL  2018                                        NaN
# 8970  Colombia  COL  2019                                        NaN
#
#       Smoking prevalence, males (% of adults)  \
# 8751                                     27.4
# ...
